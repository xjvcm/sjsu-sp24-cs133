# %%
import pandas as pd

# %%
# Different Data Options

# this input file is tab-delimited instead of comma-delimited
tsvFile = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/euk.tsv"

euk = pd.read_csv(tsvFile, sep="\t", na_values=["-"])
print(euk.head())

csvFile = (
    "https://raw.githubusercontent.com/csbfx/advpy122-data/master/top_movies_2020.csv"
)

movies = pd.read_csv(csvFile)
movies.head()
# Out:
#                       Species   Kingdom           Class  Size (Mb)      GC%  \
# 0  Emiliania huxleyi CCMP1516  Protists  Other Protists    167.676  64.5000
# 1        Arabidopsis thaliana    Plants     Land Plants    119.669  36.0529
# 2                 Glycine max    Plants     Land Plants    979.046  35.1153
# 3         Medicago truncatula    Plants     Land Plants    412.924  34.0470
# 4        Solanum lycopersicum    Plants     Land Plants    828.349  35.6991
#
#    Number of genes  Number of proteins  Publication year Assembly status
# 0          38549.0             38554.0              2013        Scaffold
# 1          38311.0             48265.0              2001      Chromosome
# 2          59847.0             71219.0              2010      Chromosome
# 3          37603.0             41939.0              2011      Chromosome
# 4          31200.0             37660.0              2010      Chromosome
#                                 Title      Gross  Gross (Adjusted)  Year
# ...

# %%
euk.columns
# Out:
# Index(['Species', 'Kingdom', 'Class', 'Size (Mb)', 'GC%', 'Number of genes',
#        'Number of proteins', 'Publication year', 'Assembly status'],
#       dtype='object')

# %%
euk[["Number of genes", "Number of proteins"]].agg([min, max])
# Out:
#      Number of genes  Number of proteins
# min              3.0                 3.0
# max         119453.0            123467.0

# %%
euk.head()
# Out:
#                       Species   Kingdom           Class  Size (Mb)      GC%  \
# 0  Emiliania huxleyi CCMP1516  Protists  Other Protists    167.676  64.5000
# 1        Arabidopsis thaliana    Plants     Land Plants    119.669  36.0529
# 2                 Glycine max    Plants     Land Plants    979.046  35.1153
# 3         Medicago truncatula    Plants     Land Plants    412.924  34.0470
# 4        Solanum lycopersicum    Plants     Land Plants    828.349  35.6991
#
#    Number of genes  Number of proteins  Publication year Assembly status
# 0          38549.0             38554.0              2013        Scaffold
# 1          38311.0             48265.0              2001      Chromosome
# 2          59847.0             71219.0              2010      Chromosome
# 3          37603.0             41939.0              2011      Chromosome
# 4          31200.0             37660.0              2010      Chromosome

# %%
movies.head()
# Out:
#                                 Title      Gross  Gross (Adjusted)  Year
# 0                  Gone with the Wind  200852579        1895421694  1939
# 1  Star Wars: Episode IV - A New Hope  460998507        1668979715  1977
# 2                  The Sound of Music  159287539        1335086324  1965
# 3          E.T. the Extra-Terrestrial  435110554        1329174791  1982
# 4                             Titanic  659363944        1270101626  1997

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             200 non-null    object
#  1   Gross             200 non-null    int64
#  2   Gross (Adjusted)  200 non-null    int64
#  3   Year              200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %% [markdown]
# # Example Questions:
#
#
# Simpler Questions:
# 1.   What Kingdoms are present in this dataset? (Eukaryote dataset)
# 2.   What are the unique Class values for each of the Kingdoms? (Eukaryote dataset)
# 3. Add a column "top_25%" to the movie dataset which contains True if the movie is in the top 25% of the Gross Adjusted values. (Movie Dataset)
# 4. Using groupby, what are the max number of genes for each Class? (Eukaryote dataset)
# 5. How many records were published in each year? (Eukaryote dataset)
#
# More Complex Questions:
# 6. What is the most recently published genome record for each Genus? (Eukaryote dataset)
# 7. What is the highest grossing movie in each decade? (Movie Dataset)
# 8. Which Class grouping has the greatest range in the number of proteins? (Eukaryote dataset)
# 9. How do genome sizes vary as sequencing technologies advance? For each Assembly Status & Class grouping, compare the max genome size from the years before 2008 to the max genome size after 2008. (Eukaryote dataset)

# %%
# Question 1
# What Kingdoms are present in this dataset? (Eukaryote dataset)
#
euk.Kingdom.unique()
# Out:
# array(['Protists', 'Plants', 'Fungi', 'Animals', 'Other'], dtype=object)

# %%
# Question 2
# What are the unique Class values for each of the Kingdoms? (Eukaryote dataset)
#

# %%
# Question 3
# Add a column "top_25%" to the movie dataset which contains True if the movie
# is in the top 25% of the Gross Adjusted values. (Movie Dataset)
#

# %%
# Question 4
# Using groupby, what are the max number of genes for each Class? (Eukaryote dataset)
#

# %%
# Question 5
# How many records were published in each year? (Eukaryote dataset)
#

# %% [markdown]
# # More complex questions

# %%
# Question 6
# What is the most recently published genome record for each Genus? (Eukaryote dataset)

# %%
# Question 7
# What is the highest grossing movie in each decade? (Movie Dataset)

# %%
# Question 8

# Possible driving question would be "Are Classes a uniform measure of biological diversity?"
# Which Class grouping has the greatest range in the number of proteins? (Eukaryote dataset)

# %%
# Question 9
# Driving Question:
# How do genome sizes vary as sequencing technologies advance?

# Proposed Methodology
# For each Assembly Status & Class grouping, compare the max genome size from
# the years before 2008 to the max genome size after 2008. (Eukaryote dataset)
